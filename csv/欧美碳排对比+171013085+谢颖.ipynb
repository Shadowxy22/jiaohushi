# %%
import pandas as pd

df = pd.read_csv('oecd_carbon_emissions_data.csv', index_col="Country")

# %%
df
# Out:
#                                      1990        1991        1992        1993  \
# Country
# United States                  6371000.54  6315615.19  6424934.36  6532069.60
# European Union (28 countries)  5649529.34  5555045.95  5379830.54  5281540.39
#
#                                      1994       1995        1996        1997  \
# Country
# United States                  6624835.79  6710067.3  6907699.05  6968461.97
# European Union (28 countries)  5255297.27  5308544.0  5418671.89  5326316.82
#
#                                      1998        1999     ...            2008  \
# Country                                                   ...
# United States                  7032526.01  7071461.46     ...      7160600.81
# European Union (28 countries)  5281519.48  5172643.92     ...      5046999.43
#
#                                      2009        2010        2011        2012  \
# Country
# United States                  6709369.15  6938591.68  6787419.03  6545969.33
# ...

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar


def bar_base() -> Bar:
    b = (
        Bar()
        .add_xaxis(x轴)
        .add_yaxis("United States", 美国)
        .add_yaxis("European Union (28 countries)", 欧洲)
        .set_global_opts(title_opts=opts.TitleOpts(title="CO2排放量", subtitle="欧美碳排对比"))
    )
    return b

# %%
b = bar_base()
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2f4195fef52b45d783b8532988f43fa0" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2f4195fef52b45d783b8532988f43fa0 = echarts.init(
#                     document.getElementById('2f4195fef52b45d783b8532988f43fa0'), 'white', {renderer: 'canvas'});
#                 var option_2f4195fef52b45d783b8532988f43fa0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x轴 = [int(x)for x in df.columns.values[-4:]]
x轴
# Out:
# [2014, 2015, 2016, 2017]

# %%
x轴 = [int(x)for x in df.columns.values[-4:]]
美国 =list(df.loc["United States"].values)[-4:]
欧洲 =list(df.loc["European Union (28 countries)"].values)[-4:]

# %%
b = bar_base()

# %%
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3055f6e55aca477d80af3d6f8b86cae2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3055f6e55aca477d80af3d6f8b86cae2 = echarts.init(
#                     document.getElementById('3055f6e55aca477d80af3d6f8b86cae2'), 'white', {renderer: 'canvas'});
#                 var option_3055f6e55aca477d80af3d6f8b86cae2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
x轴_字符串 = [str(x) for x in x轴]
x轴_字符串
# Out:
# ['2014', '2015', '2016', '2017']

# %%
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line


def line_base() -> Line:
    c = (
        Line()
        .add_xaxis(x轴_字符串)
        .add_yaxis("United States", 美国)
        .add_yaxis("European Union (28 countries)", 欧洲)
        .set_global_opts(title_opts=opts.TitleOpts(title="CO2排放量"))
    )
    return c

# %%
c = line_base()
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3cea989d36b6441888f526541eb5b14f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3cea989d36b6441888f526541eb5b14f = echarts.init(
#                     document.getElementById('3cea989d36b6441888f526541eb5b14f'), 'white', {renderer: 'canvas'});
#                 var option_3cea989d36b6441888f526541eb5b14f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
